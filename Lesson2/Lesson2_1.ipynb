# %% [markdown]
# ### Задание 1

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

plt.plot(x,y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Задание 2

# %%
t = np.linspace(0, 10, 51)
f = np.cos(t)
plt.title("График f(t)",  fontsize=16, fontweight="bold", family="serif")
plt.xlabel("Значение t", fontsize=14, family="serif")
plt.ylabel("Значение f", fontsize=14, family="serif")
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.plot(t,f, color="green")
plt.show()

# %% [markdown]
# ### Задание 3*

# %%
x = np.linspace(-3, 3, 51)
y1 = x**2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.set_size_inches(8, 6)
ax1, ax2, ax3, ax4 = ax.flatten()
fig.subplots_adjust(wspace=0.3, hspace=0.3)

ax1.plot(x, y1)
ax1.set_title("График y1")

ax2.plot(x, y2)
ax2.set_title("График y2")
ax2.set_xlim([-5, 5])

ax3.plot(x, y3)
ax3.set_title("График y3")

ax4.plot(x, y4)
ax4.set_title("График y4")
# Out:
# Text(0.5, 1.0, 'График y4')

# %% [markdown]
# ### Задание 4*

# %%
import pandas as pd
url = "creditcard.csv"
cred_df = pd.read_csv(url)
cred_df.iloc[:10, :]
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
col=cred_df["Class"].value_counts()
type(col)
col
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
plt.style.use('fivethirtyeight')
col.plot(kind="bar")

# %%
col.plot(kind="bar", logy=True)

# %%
col_v1=cred_df[['V1', 'Class']].query('Class == 1')
col_v1.drop("Class", axis=1, inplace=True)
col_v1
# Out:
#               V1
# 541    -2.312227
# 623    -3.043541
# 4920   -2.303350
# 6108   -4.397974
# 6329    1.234235
# ...          ...
# 279863 -1.927883
# 280143  1.378559
# 280149 -0.676143
# 281144 -3.113832
# 281674  1.991976
#
# [492 rows x 1 columns]

# %%
col_v0=cred_df[['V1', 'Class']].query('Class == 0')
col_v0.drop("Class", axis=1, inplace=True)
col_v0
# Out:
#                V1
# 0       -1.359807
# 1        1.191857
# 2       -1.358354
# 3       -0.966272
# 4       -1.158233
# ...           ...
# 284802 -11.881118
# 284803  -0.732789
# 284804   1.919565
# 284805  -0.240440
# 284806  -0.533413
#
# [284315 rows x 1 columns]

# %%
plt.hist(col_v0['V1'], bins=20, ec="black", alpha=0.5, density=True)
plt.hist(col_v1['V1'], bins=20, ec="black", alpha=0.5, density=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
